# %% [markdown]
# <a href="https://colab.research.google.com/github/Codebyjanhvi/Data_Analysis_-Projects/blob/main/Zomato_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=['Janhvi','sita','Neena','Geeta']
y= [1,4,3,4]
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks of Students")
plt.bar(x,y,width= 0.3,color="b")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/Zomato-data.csv')
df.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.tail(10)
# Out:
#                              name online_order book_table   rate  votes  \
# 138  Sri Murari Family Restaurant           No         No  2.9/5      0
# 139        Aramane Donne Biriyani           No         No  2.9/5      0
# 140                    Darkolates           No         No  3.3/5      0
# 141        Swaada Healthy Kitchen           No         No  3.3/5      0
# 142         Gawdaru Mane Beriyani           No         No  3.3/5      0
# 143              Melting Melodies           No         No  3.3/5      0
# 144               New Indraprasta           No         No  3.3/5      0
# 145                  Anna Kuteera          Yes         No  4.0/5    771
# 146                        Darbar           No         No  3.0/5     98
# 147                 Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 138                          250          Dining
# 139                          150          Dining
# ...

# %%
df.shape
# Out:
# (148, 7)

# %% [markdown]
# object=string in pandas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df['name']  # get clm
# Out:
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
#                ...
# 143         Melting Melodies
# 144          New Indraprasta
# 145             Anna Kuteera
# 146                   Darbar
# 147            Vijayalakshmi
# Name: name, Length: 148, dtype: object

# %%
df[['name','online_order','rate']]  #To Get Multiple Colums
# Out:
#                       name online_order   rate
# 0                    Jalsa          Yes  4.1/5
# 1           Spice Elephant          Yes  4.1/5
# 2          San Churro Cafe          Yes  3.8/5
# 3    Addhuri Udupi Bhojana           No  3.7/5
# 4            Grand Village           No  3.8/5
# ..                     ...          ...    ...
# 143       Melting Melodies           No  3.3/5
# 144        New Indraprasta           No  3.3/5
# 145           Anna Kuteera          Yes  4.0/5
# 146                 Darbar           No  3.0/5
# 147          Vijayalakshmi          Yes  3.9/5
#
# [148 rows x 3 columns]

# %%
df_type = df[df['listed_in(type)']== 'Cafes']
df_type.value_counts()
# Out:
# name                           online_order  book_table  rate   votes  approx_cost(for two people)  listed_in(type)
# 360 Atoms Restaurant And Cafe  Yes           No          3.1/5  13     400                          Cafes              1
# CAFE NOVA                      No            No          3.2/5  11     600                          Cafes              1
# Caf-Eleven                     No            No          4.0/5  424    450                          Cafes              1
# Cafe Coffee Day                No            No          3.6/5  28     900                          Cafes              1
# Cafe Shuffle                   Yes           Yes         4.2/5  150    600                          Cafes              1
# Cafe Vivacity                  Yes           No          3.8/5  90     650                          Cafes              1
# Catch-up-ino                   Yes           No          3.9/5  133    800                          Cafes              1
# ...
